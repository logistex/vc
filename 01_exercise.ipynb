# %%
import pandas as pd 
import altair as alt

# %%
from vega_datasets import data

# %%
cars = data.cars()

# %%
cars.head()
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower  Weight_in_lbs  Acceleration       Year Origin
# 0       130.0           3504          12.0 1970-01-01    USA
# 1       165.0           3693          11.5 1970-01-01    USA
# 2       150.0           3436          11.0 1970-01-01    USA
# 3       150.0           3433          12.0 1970-01-01    USA
# 4       140.0           3449          10.5 1970-01-01    USA

# %%
data.cars.url
# Out:
# 'https://cdn.jsdelivr.net/npm/vega-datasets@v1.29.0/data/cars.json'

# %%
df = pd.read_json(data.cars.url)

# %%
df.tail()
# Out:
#                 Name  Miles_per_Gallon  Cylinders  Displacement  Horsepower  \
# 401  ford mustang gl              27.0          4         140.0        86.0
# 402        vw pickup              44.0          4          97.0        52.0
# 403    dodge rampage              32.0          4         135.0        84.0
# 404      ford ranger              28.0          4         120.0        79.0
# 405       chevy s-10              31.0          4         119.0        82.0
#
#      Weight_in_lbs  Acceleration        Year  Origin
# 401           2790          15.6  1982-01-01     USA
# 402           2130          24.6  1982-01-01  Europe
# 403           2295          11.6  1982-01-01     USA
# 404           2625          18.6  1982-01-01     USA
# 405           2720          19.4  1982-01-01     USA

# %%
df = pd.DataFrame({
    'city': ['Seattle', 'Seattle', 'Seattle', 'New York', 'New York', 'New York', 'Chicago', 'Chicago', 'Chicago'],
    'month': ['Apr', 'Aug', 'Dec', 'Apr', 'Aug', 'Dec', 'Apr', 'Aug', 'Dec'],
    'precip': [2.68, 0.87, 5.31, 3.94, 4.13, 3.58, 3.62, 3.98, 2.56]
})

df
# Out:
#        city month  precip
# 0   Seattle   Apr    2.68
# 1   Seattle   Aug    0.87
# 2   Seattle   Dec    5.31
# 3  New York   Apr    3.94
# 4  New York   Aug    4.13
# 5  New York   Dec    3.58
# 6   Chicago   Apr    3.62
# 7   Chicago   Aug    3.98
# 8   Chicago   Dec    2.56

# %%
chart = alt.Chart(df).mark_point()

# %%
chart
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    y='city'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    y='precip',  
    x='city', 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    x='precip',  
    y='city', 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    alt.X('precip'),  # x='precip',  
    alt.Y('city'),    # y='city', 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    alt.Y('city'), 
    x='precip:O', 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    alt.Y('city'), 
    x='precip:N', 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    alt.Y('city'), 
    x='precip', 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    y='city', 
    x='precip',
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    alt.X('average(precip)', 
          scale=alt.Scale(domain=(0.0, 5.5))),
    y='city', 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    y='city', 
    x='average(precip)',
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    y='average(precip)',
    x='city'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    alt.X('precip'),  # x='precip', 
    alt.Y('city'), 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    alt.X('precip', scale=alt.Scale(type='log')),  # x='precip', 
    alt.Y('city'), 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    alt.X('average(precip)', 
          scale=alt.Scale(domain=(0.0, 5.5)), 
          axis=alt.Axis(title='Log-Scaled Precip')),
    alt.Y('city', axis=alt.Axis(title='City')), 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_point().encode(
    alt.X('average(precip)', 
          scale=alt.Scale(domain=(0.0, 5.5)), 
          axis=alt.Axis(title='로그 축척으로 표시한 강수량')),
    alt.Y('city', axis=alt.Axis(title='도시')), 
)
# Out:
# alt.Chart(...)

# %%
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# 0         130.0           3504          12.0 1970-01-01     USA
# 1         165.0           3693          11.5 1970-01-01     USA
# 2         150.0           3436          11.0 1970-01-01     USA
# 3         150.0           3433          12.0 1970-01-01     USA
# 4         140.0           3449          10.5 1970-01-01     USA
# ..          ...            ...           ...        ...     ...
# 401        86.0           2790          15.6 1982-01-01     USA
# 402        52.0           2130          24.6 1982-01-01  Europe
# 403        84.0           2295          11.6 1982-01-01     USA
# 404        79.0           2625          18.6 1982-01-01     USA
# 405        82.0           2720          19.4 1982-01-01     USA
#
# [406 rows x 9 columns]

# %%
cars['Km_per_Liter'] = round(cars['Miles_per_Gallon'] * 0.425, 1)

# %%
cars.head()
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower  Weight_in_lbs  Acceleration       Year Origin  Km_per_Liter
# 0       130.0           3504          12.0 1970-01-01    USA           7.6
# 1       165.0           3693          11.5 1970-01-01    USA           6.4
# 2       150.0           3436          11.0 1970-01-01    USA           7.6
# 3       150.0           3433          12.0 1970-01-01    USA           6.8
# 4       140.0           3449          10.5 1970-01-01    USA           7.2

# %%
alt.Chart(cars).mark_line().encode(
    x='Year', 
    y='Km_per_Liter', 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_point().encode(
    x='Year', 
    y='Km_per_Liter', 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_point().encode(
    x='Year', 
    y='average(Km_per_Liter)', 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_line().encode(
    x='Year', 
    y='average(Km_per_Liter)', 
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_line().encode(
    alt.X('Year'), 
    alt.Y('average(Km_per_Liter)'), 
)
# Out:
# alt.Chart(...)

# %%
line = alt.Chart(cars).mark_line().encode(
    alt.X('Year'),
    alt.Y('average(Km_per_Liter)')
)

# %%
line
# Out:
# alt.Chart(...)

# %%
circle = alt.Chart(cars).mark_circle().encode(
    alt.X('Year'),
    alt.Y('average(Km_per_Liter)')
)

# %%
circle
# Out:
# alt.Chart(...)

# %%
line + circle
# Out:
# alt.LayerChart(...)

# %%
circle + line
# Out:
# alt.LayerChart(...)

# %%
line
# Out:
# alt.Chart(...)

# %%
line.mark_circle()
# Out:
# alt.Chart(...)

# %%
line + line.mark_circle()
# Out:
# alt.LayerChart(...)

# %%
alt.Chart(cars).mark_line().encode(
    alt.X('Year'),
    alt.Y('average(Km_per_Liter)')
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_line(point=True).encode(
    alt.X('Year'),
    alt.Y('average(Km_per_Liter)')
)
# Out:
# alt.Chart(...)

# %%
hp = alt.Chart(cars).mark_line().encode(
    alt.X('Year'),
    alt.Y('average(Horsepower)')
)

# %%
hp
# Out:
# alt.Chart(...)

# %%
hp + hp.mark_circle()
# Out:
# alt.LayerChart(...)

# %%
line + line.mark_circle()
# Out:
# alt.LayerChart(...)

# %%
(hp + hp.mark_circle()) | (line + line.mark_circle())
# Out:
# alt.HConcatChart(...)

# %%
alt.Chart(cars).mark_point().encode(
    x='Km_per_Liter',
    y='Horsepower',
    color='Origin', 
).interactive()
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_point().encode(
    x='Km_per_Liter',
    y='Horsepower',
    color='Origin',
    tooltip=['Origin', 'Year'], 
).interactive()
# Out:
# alt.Chart(...)

# %%
# x-축 인코딩에 대한 선택 구간 생성하여 브러쉬로 정의
brush = alt.selection_interval(encodings=['x'])

# 브러쉬에 해당하면 진하게, 브러시에서 벗어나면 연하게
opacity = alt.condition(brush, alt.value(0.9), alt.value(0.1))

# 연도별 자동차 도수를 개괄하는 도수분포도
# 연도별 자동차 도수를 선택하는 상호작용적 구간 브러쉬 추가
overview = alt.Chart(cars).mark_bar().encode(
    alt.X('Year:O', timeUnit='year',             # 연도를 추출하고 서수형으로 지정
          axis=alt.Axis(title=None, labelAngle=45)  # 축 제목 생략, 축 눈금 레이블 각도 생략
    ),
    alt.Y('count()', title=None),                # 도수, 축 제목 생략
    opacity=opacity
).add_selection(
    brush                                        # 차트에 대한 구간 브러쉬 선택 추가
).properties(
    width=400,                                   # 차트   폭 400 픽셀로 설정
    height=50                                    # 차트 높이  50 픽셀로 설정
)

# 개괄 도수분포도에 대응하는 상세 마력-연비 산점도
# 브러쉬 선택에 대응하는 산점도 내부 점의 투명도 조절 
detail = alt.Chart(cars).mark_point().encode(
    alt.X('Horsepower'),
    alt.Y('Km_per_Liter'),
    opacity=opacity                              # 브러쉬 선택에 대응하여 투명도 조절
).properties(width=400)                          # 차트 폭을 상단 차트와 동일하게 설정

# '&' 연산자로 차트 수직 병합 
interlinked = overview & detail
interlinked
# Out:
# alt.VConcatChart(...)

# %%
alt.Chart(df).mark_bar().encode(
    x='average(precip)',
    y='city',
).to_json()
# Out:
# '{\n  "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json",\n  "config": {\n    "view": {\n      "continuousHeight": 300,\n      "continuousWidth": 400\n    }\n  },\n  "data": {\n    "name": "data-fdfbb22e8e0e89f6556d8a3b434b0c97"\n  },\n  "datasets": {\n    "data-fdfbb22e8e0e89f6556d8a3b434b0c97": [\n      {\n        "city": "Seattle",\n        "month": "Apr",\n        "precip": 2.68\n      },\n      {\n        "city": "Seattle",\n        "month": "Aug",\n        "precip": 0.87\n      },\n      {\n        "city": "Seattle",\n        "month": "Dec",\n        "precip": 5.31\n      },\n      {\n        "city": "New York",\n        "month": "Apr",\n        "precip": 3.94\n      },\n      {\n        "city": "New York",\n        "month": "Aug",\n        "precip": 4.13\n      },\n      {\n        "city": "New York",\n        "month": "Dec",\n        "precip": 3.58\n      },\n      {\n        "city": "Chicago",\n        "month": "Apr",\n        "precip": 3.62\n      },\n      {\n        "city": "Chicago",\n        "month": "Aug",\n        "precip": 3.98\n      },\n      {\n        "city": "Chicago",\n        "month": "Dec",\n        "precip": 2.56\n      }\n    ]\n  },\n  "encoding": {\n    "x": {\n      "aggregate": "average",\n      "field": "precip",\n      "type": "quantitative"\n    },\n    "y": {\n      "field": "city",\n      "type": "nominal"\n    }\n  },\n  "mark": "bar"\n}'

# %%
interlinked.save('chart/chart.html')
